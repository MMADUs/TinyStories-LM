# %%
# %load_ext autoreload
# %autoreload 2

from src.generation import ModelLoader, next_word_prediction, generate_story
from config.utils import load_config
from config.lm_v1_40M import _40M_config as model_40M_params

# %% [markdown]
# # Next Word Prediction (Causal Inference)

# %%
config = load_config(model_40M_params)
loader = ModelLoader(config, stage="pretraining", version="v1_40M", load_from_epoch=2)
# Out:
# loading model from: .output\pretrained_ckpt_v1_40M_epoch_2.pth

# %%
loader.autoregressive_attribute(
    max_new_tokens=1000,
    temperature=1.0,
    top_k=50,
    top_p=0.95,
)

# %%
response = next_word_prediction(loader, text_input="the cats is hungry")

print(response)
# Out:
# the cats is hungry. They go to the kitchen and find some food. They are hungry, but they are not hungry. They are happy to eat.
#
# "Where are they?" the cats asks the dog. They look around the kitchen. They see a red apple on a tree. The cat is happy.
#
# "Maybe they are hungry," the cat says. "They find food. Let's try it."
#
# The cats try to catch the cat. But the cat is fast and sneaky. The cat runs after them, growling. It looks at them and barks.
#
# "Go away, cat!" the cats shout. "I am fast and fast. I will catch you."
#
# But the cat does not hear them. It is too hungry. It drops the apple and runs away.
#
# The cats chases the cat. They are scared and hungry. They run after the cat.
#
# But the cat is faster. It catches up with them. It catches up with the cat. The cat hisses at them. It bites the cat's paw.
#
# The cat yelps and drops the apple. The cat hisses at the cats. It lets them pet its paw.
#
# The cats meows and scratches the cat's paw. They are scared. The cat meows. The cat purrs.
#
# "Thank you, cat," the cats say. "You are very sweet and brave."
#
# "You are welcome, kitty," the cats say. "We are sorry, cat. We were hungry and hungry too."
#
# The cat purrs and licks. It is happy. It has two friends.
#
# The cats purrs. They are happy. They are brave.

# %% [markdown]
# # Story Prompts (SFT Inference)

# %%
config = load_config(model_40M_params)
loader = ModelLoader(config, stage="finetuning", version="v1_40M", load_from_epoch=1)
# Out:
# loading model from: .output\model_ckpt_v1_40M_epoch_1.pth

# %%
loader.autoregressive_attribute(
    max_new_tokens=1000,
    temperature=1.0,
    top_k=50,
    top_p=0.95,
)

# %%
features = ["Dialogue", "BadEnding", "MoralValue"]
words = ["ride", "work", "upset"]
summary = "A story about someone stealing a bike"

features, words, summary, story = generate_story(loader, features, words, summary)

print("Features:", features)
print("\n")
print("Words:", words)
print("\n")
print("Prompt:", summary)
print("\n")
print("Story:", story)
# Out:
# Features: Dialogue, BadEnding, MoralValue
#
#
# Words: ride, work, upset
#
#
# Prompt: A story about someone stealing a bike
#
#
# Story: Once upon a time there was a little girl who liked to ride. She was very excited about it - it was always her own fun thing to do. One day, she was riding down the street when she saw a bike. She ran to it and asked it, "Can I ride it?" The bike stopped and said, "Yes, you can take it!" The girl rode the bike and she kept going. She was having so much fun that she didn't notice if it was taken. Suddenly she felt something moving inside her arm. She opened the door and saw a little house. Inside was a big, red truck. The girl was very angry. She asked the bike, "Where are you now?" The bike said, "I'm sorry, I just wanted to buy it. I think I'll get you the bus." The girl was so happy and thanked the bike for her help. The moral of this story is that it's important to work hard and help people. You can always take a break and enjoy yourself.
