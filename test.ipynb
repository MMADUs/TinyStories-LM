# %%
# %load_ext autoreload
# %autoreload 2

from inference import Generator
from config.utils import load_config
from config.lm_v1_19M import _19M_config as model_19M_params
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config = load_config(model_19M_params)
generator = Generator(config, version="v1_19M", context="castle in the sky")

# %%
generator.generate()
# Out:
# 'castle in the sky was green and her mum went to the market . She was very excited ! She showed the mother would help her , the big boat got close to the pond to the duck grew .   She walked into the sky when she looked for her to bed . She walked over again and waved goodbye to her to explore . She saw the top of the big lake .   She ran into a pond , the sea was so excited she looked around . She shouted " What should go there ?"   The bear smiled proudly said , " I \'ll get the boat !" she smiled at the little girl and grabbed the sun . It was amazed by herself and her hands before they couldn \'t wait to explore the village \'s family . Then , and she saw the duck !   The little girl smiled . She looked around the field , and the girl went out her to the little girl was so proud of the wind .   The boy was happy and kept exploring the sea with her mom .'
