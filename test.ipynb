# %%
# %load_ext autoreload
# %autoreload 2

from inference import Generator
from config.utils import load_config
from config.lm_v1_40M import _40M_config as model_40M_params
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
config = load_config(model_40M_params)
generator = Generator(config, version="v1_40M", load_from_epoch=2)
# Out:
# loading model from: .output\pretrained_ckpt_v1_40M_epoch_2.pth

# %%
response = generator.generate()
print(response)
# Out:
# Once upon a time there was a girl called Anna. She had a red scarf that she liked to wear. Anna would put it on and pretend she was a king.
#
# One day, Anna was playing in the garden when she found a big tree. She decided to take a break and sat down to rest. She felt the warm sun on her face and she felt happy.
#
# Anna lay down and closed her eyes. She closed her eyes and fell asleep. When she woke up, she smiled. She felt so comfortable and happy.
#
# Anna sat down next to the tree and started to pretend to be a king. Her voice had come from a big hole and she was having a grand time!
