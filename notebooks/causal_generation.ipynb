# %%
# %load_ext autoreload
# %autoreload 2

from src.generation import Generator
from config.utils import load_config
from config.lm_v1_40M import _40M_config as model_40M_params
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       1 get_ipython().run_line_magic('load_ext', 'autoreload')
#       2 get_ipython().run_line_magic('autoreload', '2')
# ----> 4 from .inference import Generator
#       5 from config.utils import load_config
#       6 from config.lm_v1_40M import _40M_config as model_40M_params
#
# ImportError: attempted relative import with no known parent package

# %%
config = load_config(model_40M_params)
generator = Generator(config, version="v1_40M", load_from_epoch=2)
# Out:
# loading model from: .output\pretrained_ckpt_v1_40M_epoch_2.pth

# %%
response = generator.generate()
print(response)
# Out:
# Once upon a time there was a little girl called Susie. She was three years old and loved to explore. One day she went for a walk in the forest and noticed something strange.
#
# She bent down to take a closer look. It was a soft and white animal. She was so excited to find it! She was a bit scared but she kept looking and soon she found it.
#
# "Mommy! Look!" said Susie's mommy.
#
# "Oh Susie, I found this soft animal. It was very delicate. I can't touch it," said Susie's mommy.
#
# Susie was so happy she ran home with the soft animal in her hands. She had found the delicate animal. She hugged it tightly and smiled.
