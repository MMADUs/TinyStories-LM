# %% [markdown]
# # Inference Example

# %% [markdown]
# ## Import Modules

# %%
# %load_ext autoreload
# %autoreload 2

from inference import DialogueSystem
from config import model_config
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Initialize the Dialogue System

# %%
system = DialogueSystem(model_config, version="v2", emotion="sad")

# %% [markdown]
# ## Prompting Test

# %%
prompt = "What is a firework"
ctx, prompt, response = system.chat(prompt)
print(ctx)
print(prompt)
print(response)
# Out:
# sad
# What is a firew ork
# I am so scary !  it !  My friend you have been going to be great _ comma _ that .
