# %% [markdown]
# # Inference Example

# %% [markdown]
# ## Import Modules

# %%
# %load_ext autoreload
# %autoreload 2

import pickle

from inference import DialogueSystem
from config import model_config

# %% [markdown]
# ## Initialize the Dialogue System

# %%
system = DialogueSystem(model_config, version="v1", emotion="sentimental")

# %% [markdown]
# ## Prompting Test

# %%
prompt = "Hello, how are you?"
response = system.chat(prompt)
print(response)

# %%
prompt = "Hello, how are you?"
response = system.chat(prompt)
print(response)
