# %%
from src.modules.decoder import build_model
from src.corpus import get_corpus_dataloaders

test_config = {

}

test_tdl, test_vdl, tokenizer = get_corpus_dataloaders(test_config, is_test=True)

model = build_model()

# TODO: test MoE, test QLoRA, GFLOPS measurement
